# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Absenteeism_at_work.csv')

# %% [markdown]
# ### Activities
# * Basic Data Exploration
#  * head of the dataset
#  * the shape of the dataset
#  * info of the dataset
#  * summary of the dataset
# * Handle Missing value
# * Removing duplicates
# * Outlier Treatment
# * Normalizing and Scaling( Numerical Variables)
# * Encoding Categorical variables( Dummy Variables)
# * Bivariate Analysis

# %%
df.shape
# Out:
# (740, 21)

# %%
df.head(5)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
df.drop('ID',axis=True,inplace=True)

# %%
df.columns
# Out:
# Index(['Reason for absence', 'Month of absence', 'Day of the week', 'Seasons',
#        'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Reason for absence               740 non-null    int64
#  1   Month of absence                 740 non-null    int64
#  2   Day of the week                  740 non-null    int64
#  3   Seasons                          740 non-null    int64
#  4   Transportation expense           740 non-null    int64
#  5   Distance from Residence to Work  740 non-null    int64
#  6   Service time                     740 non-null    int64
#  7   Age                              740 non-null    int64
#  8   Work load Average/day            740 non-null    float64
#  9   Hit target                       740 non-null    int64
#  10  Disciplinary failure             740 non-null    int64
#  11  Education                        740 non-null    int64
# ...

# %%
df.describe()
# Out:
#        Reason for absence  Month of absence  Day of the week     Seasons  \
# count          740.000000        740.000000       740.000000  740.000000
# mean            19.216216          6.324324         3.914865    2.544595
# std              8.433406          3.436287         1.421675    1.111831
# min              0.000000          0.000000         2.000000    1.000000
# 25%             13.000000          3.000000         3.000000    2.000000
# 50%             23.000000          6.000000         4.000000    3.000000
# 75%             26.000000          9.000000         5.000000    4.000000
# max             28.000000         12.000000         6.000000    4.000000
#
#        Transportation expense  Distance from Residence to Work  Service time  \
# count              740.000000                       740.000000    740.000000
# mean               221.329730                        29.631081     12.554054
# std                 66.952223                        14.836788      4.384873
# ...

# %%
df.dtypes
# Out:
# Reason for absence                   int64
# Month of absence                     int64
# Day of the week                      int64
# Seasons                              int64
# Transportation expense               int64
# Distance from Residence to Work      int64
# Service time                         int64
# Age                                  int64
# Work load Average/day              float64
# Hit target                           int64
# Disciplinary failure                 int64
# Education                            int64
# Son                                  int64
# Social drinker                       int64
# Social smoker                        int64
# Pet                                  int64
# Weight                               int64
# Height                               int64
# Body mass index                      int64
# Absenteeism time in hours            int64
# dtype: object

# %%
for i in df.columns:
    print('\n',df[i].value_counts())
# Out:
#  23    149
# 28    112
# 27     69
# 13     55
# 0      43
# 19     40
# 22     38
# 26     33
# 25     31
# 11     26
# 10     25
# 18     21
# 14     19
# 1      16
# 7      15
# 6       8
# 12      8
# 8       6
# 21      6
# 9       4
# 5       3
# 24      3
# 16      3
# 4       2
# 15      2
# 3       1
# 2       1
# 17      1
# Name: Reason for absence, dtype: int64
#
#  3     87
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# 0      3
# Name: Month of absence, dtype: int64
#
#  2    161
# 4    156
# 3    154
# 6    144
# 5    125
# Name: Day of the week, dtype: int64
#
#  4    195
# 2    192
# 3    183
# 1    170
# Name: Seasons, dtype: int64
#
#  179    180
# 118     92
# 225     81
# 235     58
# 289     45
# 260     42
# 291     40
# 246     30
# 155     29
# 248     24
# 361     24
# 330     16
# 369     15
# 378      8
# 228      8
# 189      8
# 233      7
# 184      7
# 157      7
# 279      6
# ...

# %%
df['Social drinker'] = np.where(df['Social drinker']==0,'No','Yes')
df['Social smoker'] = np.where(df['Social smoker']==0,'No','Yes')
df['Pet'] = np.where(df['Pet']==1,'Yes','No')
df['Disciplinary failure'] = np.where(df['Disciplinary failure']==0,'No','Yes')

# %%
for i in df.columns:
    print('\n',df[i].value_counts())
# Out:
#  23    149
# 28    112
# 27     69
# 13     55
# 0      43
# 19     40
# 22     38
# 26     33
# 25     31
# 11     26
# 10     25
# 18     21
# 14     19
# 1      16
# 7      15
# 6       8
# 12      8
# 8       6
# 21      6
# 9       4
# 5       3
# 24      3
# 16      3
# 4       2
# 15      2
# 3       1
# 2       1
# 17      1
# Name: Reason for absence, dtype: int64
#
#  3     87
# 2     72
# 10    71
# 7     67
# 5     64
# 11    63
# 8     54
# 6     54
# 9     53
# 4     53
# 1     50
# 12    49
# 0      3
# Name: Month of absence, dtype: int64
#
#  2    161
# 4    156
# 3    154
# 6    144
# 5    125
# Name: Day of the week, dtype: int64
#
#  4    195
# 2    192
# 3    183
# 1    170
# Name: Seasons, dtype: int64
#
#  179    180
# 118     92
# 225     81
# 235     58
# 289     45
# 260     42
# 291     40
# 246     30
# 155     29
# 248     24
# 361     24
# 330     16
# 369     15
# 378      8
# 228      8
# 189      8
# 233      7
# 184      7
# 157      7
# 279      6
# ...

# %%
df.head()
# Out:
#    Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                  26                 7                3        1
# 1                   0                 7                3        1
# 2                  23                 7                4        1
# 3                   7                 7                5        1
# 4                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   Hit target Disciplinary failure  Education  Son  \
# ...

# %%
df.isnull().sum()
# Out:
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Son                                0
# Social drinker                     0
# Social smoker                      0
# Pet                                0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#      Reason for absence  Month of absence  Day of the week  Seasons  \
# 16                   23                 7                6        1
# 68                   23                10                3        4
# 88                   23                11                4        4
# 109                  22                12                4        4
# 127                  27                 1                2        2
# 128                  27                 1                3        2
# 131                  27                 1                4        2
# 132                  23                 1                5        2
# 133                  27                 1                5        2
# 305                  23                10                2        4
# 351                  28                12                6        4
# 376                  27                 2                4        2
# 385                  27                 2                4        2
# ...

# %%
df.drop_duplicates(inplace=True)
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Reason for absence, Month of absence, Day of the week, Seasons, Transportation expense, Distance from Residence to Work, Service time, Age, Work load Average/day , Hit target, Disciplinary failure, Education, Son, Social drinker, Social smoker, Pet, Weight, Height, Body mass index, Absenteeism time in hours]
# Index: []

# %%
df.columns
# Out:
# Index(['Reason for absence', 'Month of absence', 'Day of the week', 'Seasons',
#        'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
df.boxplot(column=['Transportation expense'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column=['Distance from Residence to Work'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column=['Service time'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column=['Work load Average/day '])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.boxplot(column=['Absenteeism time in hours'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Uni Variate Analysis

# %%
plt.figure(figsize = (15, 4))
plt.subplot(1,3,1)
sns.boxplot(x = 'Month of absence', y = 'Disciplinary failure', data = df)
plt.subplot(1,3,2)
sns.boxplot(x = 'Day of the week', y = 'Disciplinary failure', data = df)
plt.subplot(1,3,3)
sns.boxplot(x = 'Seasons', y = 'Disciplinary failure', data = df)
plt.show()

# %%
plt.figure(figsize = (15, 4))
plt.subplot(1,3,1)
sns.boxplot(x = 'Service time', y = 'Disciplinary failure', data = df)
plt.subplot(1,3,2)
sns.boxplot(x = 'Age', y = 'Disciplinary failure', data = df)
plt.subplot(1,3,3)
sns.boxplot(x = 'Work load Average/day ', y = 'Disciplinary failure', data = df)
plt.show()

# %%
plt.figure(figsize = (15, 4))
plt.subplot(1,3,1)
sns.boxplot(x = 'Hit target', y = 'Disciplinary failure', data = df)
plt.subplot(1,3,2)
sns.boxplot(x = 'Body mass index', y = 'Disciplinary failure', data = df)
plt.subplot(1,3,3)
sns.boxplot(x = 'Absenteeism time in hours', y = 'Disciplinary failure', data = df)
plt.show()

# %%
df.columns
# Out:
# Index(['Reason for absence', 'Month of absence', 'Day of the week', 'Seasons',
#        'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
sns.FacetGrid(df, hue = "Disciplinary failure").map(sns.distplot, "Day of the week").add_legend()
plt.show()
# Out:
# C:\Users\shrey\anaconda3\envs\test\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\shrey\anaconda3\envs\test\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df, hue = "Disciplinary failure").map(sns.distplot, "Seasons").add_legend()
plt.show()
# Out:
# C:\Users\shrey\anaconda3\envs\test\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\shrey\anaconda3\envs\test\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df, hue = "Disciplinary failure").map(sns.distplot, "Transportation expense").add_legend()
plt.show()
# Out:
# C:\Users\shrey\anaconda3\envs\test\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\shrey\anaconda3\envs\test\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.head()
# Out:
#    Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                  26                 7                3        1
# 1                   0                 7                3        1
# 2                  23                 7                4        1
# 3                   7                 7                5        1
# 4                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   Hit target Disciplinary failure  Education  Son  \
# ...

# %% [markdown]
# # Bivariate Analysis
# Numerical vs. Numerical
# 1. Scatterplot
# 2. Line plot
# 3. Heatmap for correlation
# 4. Joint plot
#
# Categorical vs. Numerical
# 1. Bar chart
# 2. Violin plot
# 3. Categorical box plot
# 4.Swarm plot
#
# Two Categorical Variables
# 1. Bar chart
# 2. Grouped bar chart
# 3. Point plot

# %%
sns.heatmap(df.corr(),  annot = True)
sns.color_palette("rocket_r", as_cmap=True)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,18)
plt.show()

# %%
df.columns
# Out:
# Index(['Reason for absence', 'Month of absence', 'Day of the week', 'Seasons',
#        'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
sns.set_style('whitegrid')
sns.pairplot(df)
plt.rcParams["figure.figsize"] = (20,18)
plt.show()

# %% [markdown]
# # Data Modeling

# %%
df['Social drinker'] = np.where(df['Social drinker']=='No',0,1)
df['Social smoker'] = np.where(df['Social smoker']=='No',0,1)
df['Pet'] = np.where(df['Pet']=='No',0,1)
df['Disciplinary failure'] = np.where(df['Disciplinary failure']=='No',0,1)

# %%
from sklearn.preprocessing import StandardScaler
std_scale = StandardScaler()
to_scale = ['Reason for absence', 'Month of absence', 'Day of the week', 'Seasons',
       'Transportation expense', 'Distance from Residence to Work',
       'Service time', 'Age', 'Work load Average/day ', 'Hit target',
       'Disciplinary failure', 'Education', 'Son', 'Social drinker',
       'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
       'Absenteeism time in hours']
for i in df.columns:
    df[i] = std_scale.fit_transform(df[[i]])

# %%
df
# Out:
#      Reason for absence  Month of absence  Day of the week   Seasons  \
# 0              0.839646          0.173182        -0.625440 -1.382645
# 1             -2.227525          0.173182        -0.625440 -1.382645
# 2              0.485741          0.173182         0.076564 -1.382645
# 3             -1.401748          0.173182         0.778568 -1.382645
# 4              0.485741          0.173182         0.778568 -1.382645
# ..                  ...               ...              ...       ...
# 735           -0.575972          0.173182        -0.625440 -1.382645
# 736           -0.929876          0.173182        -0.625440 -1.382645
# 737           -2.227525         -1.884190        -0.625440 -1.382645
# 738           -2.227525         -1.884190         0.076564 -0.490371
# 739           -2.227525         -1.884190         1.480572  0.401902
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...
